# %%
import numpy as np
import pandas as pd

# %%
SOF_df=pd.read_csv("survey_results_schema.csv",index_col='Column').QuestionText

# %%
SOF_df
# Out:
# Column
# Respondent            Randomized respondent ID number (not in order ...
# MainBranch            Which of the following options best describes ...
# Hobbyist                                        Do you code as a hobby?
# Age                   What is your age (in years)? If you prefer not...
# Age1stCode            At what age did you write your first line of c...
#                                             ...
# WebframeWorkedWith    Which web frameworks have you done extensive d...
# WelcomeChange         Compared to last year, how welcome do you feel...
# WorkWeekHrs           On average, how many hours per week do you wor...
# YearsCode             Including any education, how many years have y...
# YearsCodePro          NOT including education, how many years have y...
# Name: QuestionText, Length: 61, dtype: object

# %%
Survey_Result_df=pd.read_csv("survey_results_public.csv")

# %%
Survey_Result_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
Survey_Result_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
SR_df=Survey_Result_df[selected_columns]

# %%
SR_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
len(SR_df.columns)
# Out:
# 20

# %%
SR_df.size
# Out:
# 1289220

# %%
SR_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57900 non-null  object
#  7   YearsCode               57684 non-null  object
#  8   YearsCodePro            46349 non-null  object
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
# ...

# %%
SR_df.describe()
# Out:
#                 Age   WorkWeekHrs
# count  45446.000000  41151.000000
# mean      30.834111     40.782174
# std        9.585392     17.816383
# min        1.000000      1.000000
# 25%       24.000000     40.000000
# 50%       29.000000     40.000000
# 75%       35.000000     44.000000
# max      279.000000    475.000000

# %%
SOF_df=SOF_df[selected_columns]

# %%
SOF_df
# Out:
# Column
# Country                                                  Where do you live?
# Age                       What is your age (in years)? If you prefer not...
# Gender                    Which of the following describe you, if any? P...
# EdLevel                   Which of the following best describes the high...
# UndergradMajor                        What was your primary field of study?
# Hobbyist                                            Do you code as a hobby?
# Age1stCode                At what age did you write your first line of c...
# YearsCode                 Including any education, how many years have y...
# YearsCodePro              NOT including education, how many years have y...
# LanguageWorkedWith        Which programming, scripting, and markup langu...
# LanguageDesireNextYear    Which programming, scripting, and markup langu...
# NEWLearn                  How frequently do you learn a new language or ...
# ...

# %%
SR_df["Age1stCode"]=pd.to_numeric(SR_df["Age1stCode"],errors="coerce")
SR_df["YearsCode"]=pd.to_numeric(SR_df["YearsCode"],errors="coerce")
SR_df["YearsCodePro"]=pd.to_numeric(SR_df["YearsCode"],errors="coerce")
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\505957099.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SR_df["Age1stCode"]=pd.to_numeric(SR_df["Age1stCode"],errors="coerce")
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\505957099.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SR_df["YearsCode"]=pd.to_numeric(SR_df["YearsCode"],errors="coerce")
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\505957099.py:3: SettingWithCopyWarning:
# ...

# %%
SR_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  56784.000000  41151.000000
# mean      30.834111     15.476572     12.782051     12.782051     40.782174
# std        9.585392      5.114081      9.490657      9.490657     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      6.000000     40.000000
# 50%       29.000000     15.000000     10.000000     10.000000     40.000000
# 75%       35.000000     18.000000     17.000000     17.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %%
SR_df.drop(SR_df[SR_df["Age"]<10].index,inplace=True)
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\1352482967.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SR_df.drop(SR_df[SR_df["Age"]<10].index,inplace=True)

# %%
SR_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
SR_df.drop(SR_df[SR_df["Age"]>100].index,inplace=True)
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\3727112852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SR_df.drop(SR_df[SR_df["Age"]>100].index,inplace=True)

# %%
SR_df["Gender"].value_counts()
# Out:
# Gender
# Man                                                            46007
# Woman                                                           3843
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         74
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       26
# Name: count, dtype: int64

# %%
SR_df["Gender"].where(~(SR_df["Gender"].str.contains(";",na=False)),np.nan,inplace=True)
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\2728674999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SR_df["Gender"].where(~(SR_df["Gender"].str.contains(";",na=False)),np.nan,inplace=True)

# %%
SR_df["Gender"].value_counts()
# Out:
# Gender
# Man                                                  46007
# Woman                                                 3843
# Non-binary, genderqueer, or gender non-conforming      385
# Name: count, dtype: int64

# %%
SR_df["Gender"].sample(10)
# Out:
# 53460    Man
# 39768    NaN
# 11778    Man
# 16273    Man
# 11440    Man
# 16293    Man
# 13516    Man
# 31667    NaN
# 37576    NaN
# 37365    NaN
# Name: Gender, dtype: object

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\sahil\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
SOF_df["Country"]
# Out:
# 'Where do you live?'

# %%
SR_df["Country"].unique()
# Out:
# array(['Germany', 'United Kingdom', 'Russian Federation', 'Albania',
#        'United States', 'India', 'Tunisia', 'Spain', 'Netherlands',
#        'France', 'Belgium', 'Portugal', 'Canada', 'China', 'Ukraine',
#        'Italy', 'Brazil', 'Austria', 'Mexico', 'Sweden', 'Poland',
#        'Indonesia', 'Greece', 'Israel', 'Czech Republic',
#        'Bosnia and Herzegovina', 'Bulgaria', 'Serbia', 'Switzerland',
#        'Hungary', 'Nepal', 'Slovenia', 'Uruguay', 'Denmark', 'Pakistan',
#        'Taiwan', 'Romania', 'Finland', 'Costa Rica', 'Nigeria', 'Chile',
#        'Turkey', 'Panama', 'Ireland', 'Estonia', 'Philippines',
#        'Australia', 'Nomadic', 'Peru', 'Cyprus', 'Sri Lanka', 'Kenya',
#        'Norway', 'Kyrgyzstan', 'Iran', 'Croatia', 'Egypt', 'Argentina',
#        'Ghana', 'Latvia', 'Morocco', 'Bangladesh', 'Ecuador', 'Haiti',
#        'Venezuela, Bolivarian Republic of...', 'Colombia', 'Lithuania',
#        'El Salvador', 'Honduras', 'Ethiopia', 'Lebanon', 'Uganda',
# ...

# %%
SR_df["Country"].nunique()
# Out:
# 183

# %%
Country_count=SR_df["Country"].value_counts().head(15)
Country_count
# Out:
# Country
# United States         12468
# India                  8401
# United Kingdom         3896
# Germany                3890
# Canada                 2191
# France                 1898
# Brazil                 1818
# Netherlands            1341
# Poland                 1278
# Australia              1208
# Spain                  1161
# Italy                  1117
# Russian Federation     1092
# Sweden                  886
# Pakistan                809
# Name: count, dtype: int64

# %%
sns.set_style("whitegrid")

# %%
plt.figure(figsize=(12,9))
sns.barplot(x=Country_count.index,y=Country_count,palette="viridis")
plt.xticks(rotation=75)
plt.title("Programmer Acc. To Country")
plt.show();
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\2319998818.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=Country_count.index,y=Country_count,palette="viridis")

# %%
plt.figure(figsize=(8,6))
sns.histplot(SR_df["Age"],bins=np.arange(20,80,5),color="seagreen")
plt.title("Age");

# %%
bin=[0,10,18,30,45,60,float("inf")]

# %%
import math
def age_grp(x):
    if math.isnan(x):
        return "NaN"
    elif x<10:
        return "less than 10"
    elif x>=10 and x<18:
        return "10-18"
    elif x>=18 and x<30:
        return "18-30"
    elif x>=30 and x<45:
        return "30-45"
    elif x>=45 and x<60:
        return "45-60" 
    
    else :
        return "above 60"

# %%
SR_df["Age_group"]=SR_df["Age"].apply(age_grp)
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\1252126380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SR_df["Age_group"]=SR_df["Age"].apply(age_grp)

# %%
SR_df[["Age","Age_group"]].sample(10)
# Out:
#         Age Age_group
# 16910   NaN       NaN
# 58251  25.0     18-30
# 25833  21.0     18-30
# 63676   NaN       NaN
# 5887   30.0     30-45
# 43552   NaN       NaN
# 10265  29.0     18-30
# 28888  45.0     45-60
# 15083  45.0     45-60
# 45535   NaN       NaN

# %%
AGE_GRP_df=SR_df.dropna(subset=["Age"])

# %%
AGE_GRP_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45436 entries, 3 to 64441
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 45436 non-null  object
#  1   Age                     45436 non-null  float64
#  2   Gender                  44575 non-null  object
#  3   EdLevel                 44448 non-null  object
#  4   UndergradMajor          39674 non-null  object
#  5   Hobbyist                45436 non-null  object
#  6   Age1stCode              45051 non-null  float64
#  7   YearsCode               44660 non-null  float64
#  8   YearsCodePro            44660 non-null  float64
#  9   LanguageWorkedWith      45019 non-null  object
#  10  LanguageDesireNextYear  42953 non-null  object
#  11  NEWLearn                43775 non-null  object
#  12  NEWStuck                44906 non-null  object
#  13  Employment              45313 non-null  object
# ...

# %%
df=AGE_GRP_df["Age_group"].value_counts().reindex(["less than 10", "10-18", "18-30", "30-45", "45-60", "above 60"], fill_value=0)

# %%
df
# Out:
# Age_group
# less than 10        0
# 10-18            1191
# 18-30           22729
# 30-45           17481
# 45-60            3430
# above 60          605
# Name: count, dtype: int64

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,6))
sns.barplot(df,palette="cubehelix")
plt.xticks(rotation=75)
plt.title("AGE_Group");
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\1074397190.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(df,palette="cubehelix")

# %%
SOF_df.Gender
# Out:
# 'Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.'

# %%
Gender_Type=SR_df["Gender"].value_counts(dropna=False)

# %%
plt.pie(Gender_Type,labels=Gender_Type.index,autopct='%1.1f%%')
plt.title("Gender Diversity")
plt.legend;

# %%
SOF_df.EdLevel
# Out:
# 'Which of the following best describes the highest level of formal education that you’ve completed?'

# %%
edu_count=SR_df["EdLevel"].value_counts()
edu_count
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          26539
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       13111
# Some college/university study without earning a degree                                 7238
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     4770
# Associate degree (A.A., A.S., etc.)                                                    1843
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             1690
# Primary/elementary school                                                               941
# Professional degree (JD, MD, etc.)                                                      800
# I never completed any formal education                                                  490
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,6))
plt.title(SOF_df["EdLevel"])
sns.barplot(x=edu_count,y=edu_count.index,palette="Greens");
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\2242870130.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=edu_count,y=edu_count.index,palette="Greens");

# %%
SOF_df.UndergradMajor
# Out:
# 'What was your primary field of study?'

# %%
A=SR_df["UndergradMajor"].value_counts()

# %%
B=SR_df.UndergradMajor.count()

# %%
per_UndergradMajor=A*100/B

# %%
per_UndergradMajor
# Out:
# UndergradMajor
# Computer science, computer engineering, or software engineering                   61.927082
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       9.323580
# Information systems, information technology, or system administration              7.984075
# A natural science (such as biology, chemistry, physics, etc.)                      4.324462
# Mathematics or statistics                                                          3.626272
# Web development or web design                                                      3.508600
# A business discipline (such as accounting, finance, marketing, etc.)               2.696660
# A humanities discipline (such as literature, history, philosophy, etc.)            1.974936
# A social science (such as anthropology, psychology, political science, etc.)       1.829806
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)     1.421875
# ...

# %%
plt.figure(figsize=(10,7))
plt.title(SOF_df["UndergradMajor"])

sns.barplot(x=per_UndergradMajor,y=per_UndergradMajor.index,palette="colorblind");
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\3699729244.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=per_UndergradMajor,y=per_UndergradMajor.index,palette="colorblind");

# %%
SOF_df["Employment"]
# Out:
# 'Which of the following best describes your current employment status?'

# %%
Emp_count=SR_df["Employment"].value_counts()

# %%
plt.figure(figsize=(10,7))
plt.title(SOF_df["Employment"])

sns.barplot(x=Emp_count,y=Emp_count.index,palette="RdPu");
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\2275390938.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=Emp_count,y=Emp_count.index,palette="RdPu");

# %%
SOF_df.DevType
# Out:
# 'Which of the following describe you? Please select all that apply.'

# %%
SR_df["DevType"].value_counts()
# Out:
# DevType
# Developer, full-stack                                                                                                                                                                                                                    4423
# Developer, back-end                                                                                                                                                                                                                      3086
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                                                                           2226
# Developer, back-end;Developer, full-stack                                                                                                                                                                                                1476
# ...

# %%
SR_df["DevType"].str.split(";")
# Out:
# 0        [Developer, desktop or enterprise applications...
# 1               [Developer, full-stack, Developer, mobile]
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 64456                                [Senior executive/VP]
# 64457                                                  NaN
# 64458                                                  NaN
# 64459                                                  NaN
# 64460                                                  NaN
# Name: DevType, Length: 64451, dtype: object

# %%
def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    options = []
    # Iterate over the column
    for idx, value  in col_series[col_series.notnull()].iteritems():
        # Break each value into list of options
        for option in value.split(';'):
            # Add the option as a column to result
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True
    return result_df[options]

# %%
def split_multi(col):
    result_df=col.to_frame()
    options=[]
    for idx,value in col[col.notnull()].items():
        for option in value.split(";"):
            if not option in result_df.columns:
                options.append(option)
                result_df[option]=False
            result_df.at[idx,option]=True
    return result_df[options]

# %%
Dev_type=split_multi(SR_df["DevType"])

# %%
Dev_type
# Out:
#        Developer, desktop or enterprise applications  Developer, full-stack  \
# 0                                               True                   True
# 1                                              False                   True
# 2                                              False                  False
# 3                                              False                  False
# 4                                              False                  False
# ...                                              ...                    ...
# 64456                                          False                  False
# 64457                                          False                  False
# 64458                                          False                  False
# 64459                                          False                  False
# 64460                                          False                  False
#
# ...

# %%
dev_type_sum=Dev_type.sum().sort_values(ascending=False)

# %%
SOF_df.LanguageWorkedWith
# Out:
# 'Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)'

# %%
language=split_multi(SR_df["LanguageWorkedWith"])

# %%
language_sum=language.sum().sort_values(ascending=False)

# %%
language_sum
# Out:
# JavaScript               38816
# HTML/CSS                 36176
# SQL                      31407
# Python                   25285
# Java                     23070
# Bash/Shell/PowerShell    18978
# C#                       18038
# PHP                      15003
# TypeScript               14575
# C++                      13702
# C                        12485
# Go                        5037
# Kotlin                    4467
# Ruby                      4045
# Assembly                  3551
# VBA                       3498
# Swift                     3395
# R                         3287
# Rust                      2928
# Objective-C               2338
# Dart                      2279
# Scala                     2051
# Perl                      1795
# Haskell                   1221
# Julia                      518
# dtype: int64

# %%
plt.figure(figsize=(9,6))
plt.title("Languages used in the past year")
sns.barplot(x=language_sum,y=language_sum.index,color="pink")
plt.xlabel("count");

# %%
lang_interested=split_multi(SR_df["LanguageDesireNextYear"])
lang_interested
# Out:
#           C#  HTML/CSS  JavaScript  Python  Swift  Objective-C   Java   Ruby  \
# 0       True      True        True   False  False        False  False  False
# 1      False     False       False    True   True        False  False  False
# 2      False     False       False    True   True         True  False  False
# 3      False     False       False   False  False        False  False  False
# 4      False     False       False   False  False        False   True   True
# ...      ...       ...         ...     ...    ...          ...    ...    ...
# 64456  False     False       False   False  False        False  False  False
# 64457   True      True        True    True   True         True   True   True
# 64458  False     False       False   False  False        False  False  False
# 64459  False      True        True   False  False        False   True  False
# 64460   True      True        True   False  False        False   True  False
#
# ...

# %%
per_lang_interested=lang_interested.mean().sort_values(ascending=False)*100
per_lang_interested
# Out:
# Python                   41.394237
# JavaScript               40.627764
# HTML/CSS                 32.221377
# SQL                      30.978573
# TypeScript               26.603156
# C#                       21.213015
# Java                     20.578424
# Go                       19.551287
# Bash/Shell/PowerShell    18.192115
# Rust                     16.387643
# C++                      15.133978
# Kotlin                   14.853144
# PHP                      11.023879
# C                         9.449039
# Swift                     8.750834
# Dart                      7.355976
# R                         6.625188
# Ruby                      6.490202
# Scala                     5.374626
# Haskell                   4.646941
# Assembly                  3.826163
# Julia                     2.575600
# Objective-C               2.364587
# Perl                      1.782750
# VBA                       1.635351
# dtype: float64

# %%
plt.ylabel("interested languages")
plt.xlabel("Percentage")
sns.barplot(x=per_lang_interested,y=per_lang_interested.index,palette="husl");
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_19820\2245860742.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=per_lang_interested,y=per_lang_interested.index,palette="husl");

# %%
AGE_1st=SR_df["Age1stCode"].value_counts().sort_values(ascending=False).head(15)
AGE_1st
# Out:
# Age1stCode
# 15.0    5618
# 14.0    5514
# 16.0    5462
# 18.0    5382
# 12.0    5080
# 13.0    4186
# 17.0    3973
# 10.0    3424
# 19.0    3120
# 20.0    2452
# 11.0    2358
# 8.0     1624
# 9.0     1231
# 21.0    1221
# 22.0     999
# Name: count, dtype: int64

# %%
plt.title(SOF_df.Age1stCode)
sns.histplot(x=SR_df.Age1stCode, bins=30, kde=True);
